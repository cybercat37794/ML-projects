# %%
import scipy.io as sio
GOOGLE_COLAB = True
if GOOGLE_COLAB:
    from google.colab import drive, files
    drive.mount('/content/drive')
    path = "/content/drive/My Drive/Cifar-10 dataset/"
dataset = path + 'data_batch_1.mat'
# Out:
# Mounted at /content/drive

# %%
mat_contents = sio.loadmat(dataset)
images_original = mat_contents['data']
label = mat_contents['data']
print('image_original shape: ', images_original.shape)
# Out:
# image_original shape:  (10000, 3072)

# %%
import numpy as np

images = np.transpose(images_original)
print("images.shape", images.shape)
imgs = np.reshape(images, [32, 32, 3, -1], order = "F")
print("imgs.shape ", imgs.shape)
# Out:
# images.shape (3072, 10000)
# imgs.shape  (32, 32, 3, 10000)

# %%
from matplotlib import pyplot as plt 
plt.imshow(imgs[:, :, :, 45])
print("imgs[:, :, :, 40].shape", imgs[:, :, :, 45].shape)
# Out:
# imgs[:, :, :, 40].shape (32, 32, 3)

# %%
from scipy import misc
import cv2
from math import sqrt 
from numpy import ndarray

test_image = path + 'TestImage.jpg'

img0 = cv2.imread(test_image)
plt.figure()
plt.imshow(img0)

img1 = cv2.cvtColor(img0, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img1)

img2 = cv2.resize(img1, (32, 32))
plt.figure()
plt.imshow(img2)

img3 = np.reshape(img2, [3072, 1], order = 'F')
print('img3.shape', img3.shape)
# Out:
# img3.shape (3072, 1)

# %%
def euclidean_distance(row1, row2):
    distance = 0.0
    for i in range(len(row1)):
        distance = distance + (row1[i] - row2[i]) ** 2
    return sqrt(distance)

# %%
 dist = np.zeros(10000)

 for i in range (10000):
     selectedimg = images[0:3072, i]
     dist[i] = euclidean_distance(img3, selectedimg)

print("Euclidean Distance: ", dist)
print("Minimum Distance: ", min(dist))
mindist = np.argmin(dist)
print("Index of Minimum Distance: ", mindist)
# Out:
# Euclidean Distance:  [577.56038645 572.89527839 569.44271002 ... 568.09770286 573.83969887
#  567.27506555]
# Minimum Distance:  548.9626581107316
# Index of Minimum Distance:  4618

# %%
plt.imshow(imgs[:, :, :, mindist])

# %%
np.argsort(dist)
# Out:
# array([4618, 6390, 9869, ..., 7908, 6594, 8929])

# %% [markdown]
# # Testing Image 2

# %%
test_image = path + 'TestImage2.jpg'

img0 = cv2.imread(test_image)
plt.figure()
plt.imshow(img0)

img1 = cv2.cvtColor(img0, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img1)

img2 = cv2.resize(img1, (32, 32))
plt.figure()
plt.imshow(img2)

img3 = np.reshape(img2, [3072, 1], order = 'F')
print('img3.shape', img3.shape)
# Out:
# img3.shape (3072, 1)

# %%
 dist = np.zeros(10000)

 for i in range (10000):
     selectedimg = images[0:3072, i]
     dist[i] = euclidean_distance(img3, selectedimg)

print("Euclidean Distance: ", dist)
print("Minimum Distance: ", min(dist))
mindist = np.argmin(dist)
print("Index of Minimum Distance: ", mindist)
# Out:
# Euclidean Distance:  [563.99024814 571.69397408 569.84383826 ... 577.48939384 572.2840204
#  570.8817741 ]
# Minimum Distance:  530.5751596145451
# Index of Minimum Distance:  8072

# %%
plt.imshow(imgs[:, :, :, mindist])

# %% [markdown]
# # Testing Image 3

# %%
test_image = path + 'TestImage3.jpg'

img0 = cv2.imread(test_image)
plt.figure()
plt.imshow(img0)

img1 = cv2.cvtColor(img0, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img1)

img2 = cv2.resize(img1, (32, 32))
plt.figure()
plt.imshow(img2)

img3 = np.reshape(img2, [3072, 1], order = 'F')
print('img3.shape', img3.shape)
# Out:
# img3.shape (3072, 1)

# %%
 dist = np.zeros(10000)

 for i in range (10000):
     selectedimg = images[0:3072, i]
     dist[i] = euclidean_distance(img3, selectedimg)

print("Euclidean Distance: ", dist)
print("Minimum Distance: ", min(dist))
mindist = np.argmin(dist)
print("Index of Minimum Distance: ", mindist)
# Out:
# Euclidean Distance:  [574.14893538 567.59844961 566.37796567 ... 567.31120208 570.39723001
#  571.75169436]
# Minimum Distance:  503.3309050714053
# Index of Minimum Distance:  906

# %%
plt.imshow(imgs[:, :, :, mindist])
